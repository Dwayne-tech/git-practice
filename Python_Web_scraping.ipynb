# %% [markdown]
# <a href="https://colab.research.google.com/github/Dwayne-tech/git-practice/blob/main/Python_Web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import requests
import string
from bs4 import BeautifulSoup


def get_and_parse_html(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"):
    response = requests.get(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA")
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup


# Write a function to Extract article title
def extract_article_title(soup):
    title = soup.find('h1', id='firstHeading').text
    return title


# Write a function to Extract article text for each paragraph
def extract_article_text(soup):
    headings = soup.find_all(['h2', 'h3', 'h4'])
    paragraphs = soup.find_all('p')

    article_text = {}
    current_heading = None
    for element in headings + paragraphs:
        if element.name in ['h2', 'h3', 'h4']:
            current_heading = element.text
            article_text[current_heading] = []
        elif element.name == 'p':
            article_text[current_heading].append(element.text)

    return article_text


# Write a function to collect every link that redirects to another Wikipedia page
def extract_internal_links(soup):
    # The following line was not indented and caused the IndentationError
    links = soup.find_all('a', href=lambda href: href and href.startswith('/wiki/'))
    internal_links = [link['href'] for link in links]
    return internal_links


# Wrap all the previous functions
def extract_wikipedia_info(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"):
    soup = get_and_parse_html(url)
    title = extract_article_title(soup)
    article_text = extract_article_text(soup)
    internal_links = extract_internal_links(soup)

import requests
import string
from bs4 import BeautifulSoup


def get_and_parse_html(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"):
    response = requests.get(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA")
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup


# Write a function to Extract article title
def extract_article_title(soup):
    title = soup.find('h1', id='firstHeading').text
    return title


# Write a function to Extract article text for each paragraph
def extract_article_text(soup):
    headings = soup.find_all(['h2', 'h3', 'h4'])
    paragraphs = soup.find_all('p')

    article_text = {}
    current_heading = None
    for element in headings + paragraphs:
        if element.name in ['h2', 'h3', 'h4']:
            current_heading = element.text
            article_text[current_heading] = []
        elif element.name == 'p':
            article_text[current_heading].append(element.text)

    return article_text


# Write a function to collect every link that redirects to another Wikipedia page
def extract_internal_links(soup):
    links = soup.find_all('a', href=lambda href: href and href.startswith('/wiki/'))
    internal_links = [link['href'] for link in links]
    return internal_links


# Wrap all the previous functions
def extract_wikipedia_info(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"):
    soup = get_and_parse_html(url)
    title = extract_article_title(soup)
    article_text = extract_article_text(soup)
    internal_links = extract_internal_links(soup)

    return {'title': title, 'text': article_text, 'internal_links': internal_links}
# Test the last function on a Wikipedia page of your choice
# Test the function
url = "https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"
result = extract_wikipedia_info(url)
print(result['title'])
print(result['text'])
print(result['internal_links'])


print(result['text'])
print(result['internal_links'])

from bs4 import BeautifulSoup


def get_and_parse_html(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"):
    response = requests.get(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA")
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup


# Write a function to Extract article title
def extract_article_title(soup):
    title = soup.find('h1', id='firstHeading').text
    return title


# Write a function to Extract article text for each paragraph
def extract_article_text(soup):
    headings = soup.find_all(['h2', 'h3', 'h4'])
    paragraphs = soup.find_all('p')

    article_text = {}
    current_heading = None
    for element in headings + paragraphs:
        if element.name in ['h2', 'h3', 'h4']:
            current_heading = element.text
            article_text[current_heading] = []
        elif element.name == 'p':
            article_text[current_heading].append(element.text)

    return article_text


# Write a function to collect every link that redirects to another Wikipedia page
def extract_internal_links(soup):
    links = soup.find_all('a', href=lambda href: href and href.startswith('/wiki/'))
    internal_links = [link['href'] for link in links]
    return internal_links


# Wrap all the previous functions
def extract_wikipedia_info(url="https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"):
    soup = get_and_parse_html(url)
    title = extract_article_title(soup)
    article_text = extract_article_text(soup)
    internal_links = extract_internal_links(soup)

    return {'title': title, 'text': article_text, 'internal_links': internal_links}
# Test the last function on a Wikipedia page of your choice
# Test the function
url = "https://en.wikipedia.org/wiki/Mercedes-Benz_GLA"
result = extract_wikipedia_info(url)
print(result['title'])
print(result['text'])
print(result['internal_links'])
print(input())
# Out:
# Mercedes-Benz GLA
# ...
